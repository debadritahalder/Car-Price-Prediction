# %%
import pandas as pd

# Loading the full raw data locally
img_table = pd.read_csv("../data/raw/Image_table.csv")

# Creating sample version of the dataset having first 1000 rows   
img_table_sample = img_table.head(1000)

# Saving the sample dataset
img_table_sample.to_csv("../data/raw/Image_table_sample.csv", index=False)
